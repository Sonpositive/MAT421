# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonpositive/MAT421/blob/main/ModuleB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 17.4 Lagrange Polynomial Interpolation
#
# this method finds a single polynomial that goes through all the data points.

# %%
from scipy.interpolate import lagrange
import matplotlib.pyplot as plt
import numpy as np



x = [0,1,2]
y = [5, 1,9]


x_new = np.arange(0,4,0.1)

f = lagrange(x,y)
fig = plt.figure(figsize = (10,8))
plt.plot(x_new,f(x_new), 'b',x,y, 'ro')
plt.title('Lagrange Polynomial')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
from scipy.interpolate import lagrange
import matplotlib.pyplot as plt
import numpy as np


x = [0,3,6,9,12]
y = [5,3,9,11,6]


x_new = np.arange(0,15,0.1)

f = lagrange(x,y)
fig = plt.figure(figsize = (10,8))
plt.plot(x,y,label='Acutal')
plt.plot(x_new,f(x_new), 'b',x,y, 'ro', label ='Approximation')
plt.title('Lagrange Polynomial')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.legend
plt.show()

# %% [markdown]
# 17.5 Newton's Polynomial interpolation

# %%
import matplotlib.pyplot as plt
import numpy as np


def divided_diff(x, y):

  n = len(y)
  coef = np.zeros([n, n])
# the first column is y
  coef[:,0] = y
  for j in range(1,n):
    for i in range(n-j):
      coef[i][j] = \
      (coef[i+1][j-1] - coef[i][j-1]) / (x[i+j]-x[i])
  return coef

def newton_poly(coef, x_data, x):

  n = len(x_data) - 1
  p = coef[n]
  for k in range(1,n+1):
    p = coef[n-k] + (x -x_data[n-k])*p
  return p

x = np.array([0,1,2])
y = np.array([5, 1,9])

a_s = divided_diff(x,y)[0,:]

x_new = np.arange(-1,3,0.1)
y_new = newton_ploy(a_s,x, x_new)

plt.figure(figsize = (12,8))
plt.plot(x,y, 'bo')
plt.plot(x_new,y_new)

# %%
x = np.array([0,3,6,9,12])
y = np.array([5,3,9,11,6])

a_s = divided_diff(x,y)[0,:]

x_new = np.arange(-1,13,0.1)
y_new = newton_ploy(a_s,x, x_new)

plt.figure(figsize = (12,8))
plt.plot(x,y, 'bo')
plt.plot(x_new,y_new)
